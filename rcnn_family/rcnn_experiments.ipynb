# %%
import platform, torch
print("OS:", platform.platform())
print("PyTorch:", torch.__version__)
print("torch.version.cuda:", torch.version.cuda)
print("GPU count:", torch.cuda.device_count())
print("MPS available:", getattr(torch.backends, "mps", None) and torch.backends.mps.is_available())
print("CUDA available:", torch.cuda.is_available())
if torch.cuda.is_available():
    print("CUDA device count:", torch.cuda.device_count())
    print("Device 0:", torch.cuda.get_device_name(0))
    print("CUDA runtime:", torch.version.cuda)
# Out:
# OS: Linux-6.6.87.2-microsoft-standard-WSL2-x86_64-with-glibc2.35
# PyTorch: 2.8.0+cu128
# torch.version.cuda: 12.8
# GPU count: 1
# MPS available: False
# CUDA available: True
# CUDA device count: 1
# Device 0: NVIDIA T550 Laptop GPU
# CUDA runtime: 12.8

# %%
# rcnn_experiments.ipynb – Cell 1
import torch
import torchvision.transforms as T
from torch.utils.data import DataLoader
from torchvision.ops import box_iou
from torch.cuda.amp import autocast, GradScaler

from rcnn_dataset import FruitDetectionDataset
from rcnn_model import get_faster_rcnn_model

import os
from PIL import Image, ImageDraw

DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", DEVICE)

# CHANGE THIS if you have a different number of fruit classes
NUM_FRUIT_CLASSES = 10
NUM_CLASSES = NUM_FRUIT_CLASSES + 1   # +1 for background

# Fill in your actual class names in order
CLASS_NAMES = [
    "background",
    "apple",
    "avocado",
    "banana",
    "kiwi",
    "lemon",
    "orange",
    "pear",
    "pomegranate",
    "strawberry",
    "watermelon",
]
# Out:
# Using device: cuda

# %%
dataset = FruitDetectionDataset(
    images_dir="../dataset/split/train/images",
    labels_dir="../dataset/split/train/labels")

# %%
test_img = dataset.__getitem__(0)

# %%
train_imgs   = "../dataset/split/train/images"
train_labels = "../dataset/split/train/labels"

val_imgs     = "../dataset/split/val/images"
val_labels   = "../dataset/split/val/labels"

print("Train images dir:", train_imgs)
print("Train labels dir:", train_labels)
print("Val images dir:", val_imgs)
print("Val labels dir:", val_labels)

import torchvision.transforms as T
from torch.utils.data import DataLoader

def get_transforms(train=True):
    transforms = [T.ToTensor()]
    if train:
        transforms.extend([
            T.RandomHorizontalFlip(0.5),
            T.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1),
            T.RandomAdjustSharpness(sharpness_factor=2, p=0.5),
            # Can also add: RandomRotation, RandomAffine, GaussianBlur
        ])
    return T.Compose(transforms)

def collate_fn(batch):
    return tuple(zip(*batch))

# create datasets
train_dataset = FruitDetectionDataset(
    images_dir=train_imgs,
    labels_dir=train_labels,
    transforms=get_transforms(train=True),
)

val_dataset = FruitDetectionDataset(
    images_dir=val_imgs,
    labels_dir=val_labels,
    transforms=get_transforms(train=False),
)

print("Train samples:", len(train_dataset))
print("Val samples:", len(val_dataset))

# data loaders
train_loader = DataLoader(
    train_dataset,
    batch_size=2,
    shuffle=True,
    num_workers=0,
    collate_fn=collate_fn,
)

val_loader = DataLoader(
    val_dataset,
    batch_size=2,
    shuffle=False,
    num_workers=0,
    collate_fn=collate_fn,
)
# Out:
# Train images dir: ../dataset/split/train/images
# Train labels dir: ../dataset/split/train/labels
# Val images dir: ../dataset/split/val/images
# Val labels dir: ../dataset/split/val/labels
# Train samples: 967
# Val samples: 278

# %%
model = get_faster_rcnn_model(num_classes=NUM_CLASSES)
model.to(DEVICE)

params = [p for p in model.parameters() if p.requires_grad]
optimizer = torch.optim.AdamW(
    params,
    lr=0.0001,
    weight_decay=0.0001
)

lr_scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
    optimizer, mode='max', factor=0.5, patience=5
)

print("Model ready.")
# Out:
# Model ready.

# %%
scaler = GradScaler()

def train_one_epoch(model, optimizer, data_loader, epoch):
    model.train()
    total_loss = 0.0

    for images, targets in data_loader:
        images = [img.to(DEVICE) for img in images]
        targets = [{k: v.to(DEVICE) for k, v in t.items()} for t in targets]

        with autocast():
            loss_dict = model(images, targets)
            losses = sum(loss for loss in loss_dict.values())

        optimizer.zero_grad()
        scaler.scale(losses).backward()
        scaler.step(optimizer)
        scaler.update()

        total_loss += losses.item()

    avg_loss = total_loss / len(data_loader)
    print(f"Epoch {epoch}: train loss = {avg_loss:.4f}")
    return total_loss / len(data_loader)


@torch.no_grad()
def evaluate_simple(model, data_loader):
    """
    Very simple evaluation: computes mean IoU between
    predicted boxes and ground-truth boxes.
    """
    model.eval()
    total_iou = 0.0
    n_boxes = 0

    for images, targets in data_loader:
        images = [img.to(DEVICE) for img in images]
        outputs = model(images)

        for out, tgt in zip(outputs, targets):
            if len(out["boxes"]) == 0 or len(tgt["boxes"]) == 0:
                continue

            ious = box_iou(out["boxes"].cpu(), tgt["boxes"])
            max_iou, _ = ious.max(dim=0)   # best IoU per GT box
            total_iou += max_iou.sum().item()
            n_boxes += len(max_iou)

    if n_boxes > 0:
        mean_iou = total_iou / n_boxes
        print(f"Mean IoU over GT boxes: {mean_iou:.3f}")
        return mean_iou
    else:
        print("No boxes to evaluate (check labels).")
        return 0.0
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_11088\2331203523.py:1: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = GradScaler()

# %%
max_epochs = 200          
patience = 10             
min_delta = 1e-3          

train_losses = []
val_ious = []

best_loss = float("inf")
best_state = None
epochs_no_improve = 0
best_val_iou = 0.0

for epoch in range(1, max_epochs + 1):
    print(f"\n===== Epoch {epoch}/{max_epochs} =====")
    train_loss = train_one_epoch(model, optimizer, train_loader, epoch)
    train_losses.append(train_loss)

    # LR schedule step
    lr_scheduler.step(val_iou)

    # simple evaluation (IoU)
    val_iou = evaluate_simple(model, val_loader)
    val_ious.append(val_iou)

    # Early stopping on validation performance
    if val_iou > best_val_iou + min_delta:
        best_val_iou = val_iou
        epochs_no_improve = 0
        best_state = model.state_dict()
        print(f"New best val IoU: {best_val_iou:.4f} (model state saved)")
    #elif train_loss < best_loss - min_delta:
    #    best_loss = train_loss
    #    epochs_no_improve = 0
    #    best_state = model.state_dict()  # keep best weights
    #    print(f"New best loss: {best_loss:.4f} (model state saved)")
    else:
        epochs_no_improve += 1
        print(f"No significant improvement for {epochs_no_improve} epoch(s).")

    if epochs_no_improve >= patience:
        print(f"\n⏹ Early stopping triggered: "
              f"no improvement > {min_delta} for {patience} epochs.")
        break

print(f"\nTraining finished. Best train loss: {best_loss:.4f}")
# Out:
# ===== Epoch 1/200 =====
# C:\Users\Admin\AppData\Local\Temp\ipykernel_11088\2331203523.py:11: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# C:\Users\Admin\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\PIL\Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch 1: train loss = 0.5375
# Mean IoU over GT boxes: 0.767
# New best val IoU: 0.7669 (model state saved)
#
# ===== Epoch 2/200 =====
# Epoch 2: train loss = 0.4931
# Mean IoU over GT boxes: 0.784
# New best val IoU: 0.7837 (model state saved)
#
# ===== Epoch 3/200 =====
# Epoch 3: train loss = 0.4935
# Mean IoU over GT boxes: 0.767
# No significant improvement for 1 epoch(s).
#
# ===== Epoch 4/200 =====
# Epoch 4: train loss = 0.4545
# Mean IoU over GT boxes: 0.770
# No significant improvement for 2 epoch(s).
#
# ===== Epoch 5/200 =====
# Epoch 5: train loss = 0.4505
# Mean IoU over GT boxes: 0.783
# No significant improvement for 3 epoch(s).
#
# ===== Epoch 6/200 =====
# Epoch 6: train loss = 0.4308
# Mean IoU over GT boxes: 0.776
# No significant improvement for 4 epoch(s).
#
# ===== Epoch 7/200 =====
# Epoch 7: train loss = 0.3751
# Mean IoU over GT boxes: 0.806
# New best val IoU: 0.8058 (model state saved)
#
# ===== Epoch 8/200 =====
# Epoch 8: train loss = 0.3546
# Mean IoU over GT boxes: 0.797
# No significant improvement for 1 epoch(s).
#
# ===== Epoch 9/200 =====
# Epoch 9: train loss = 0.3434
# Mean IoU over GT boxes: 0.794
# No significant improvement for 2 epoch(s).
#
# ===== Epoch 10/200 =====
# Epoch 10: train loss = 0.3308
# Mean IoU over GT boxes: 0.794
# No significant improvement for 3 epoch(s).
#
# ===== Epoch 11/200 =====
# Epoch 11: train loss = 0.3142
# Mean IoU over GT boxes: 0.782
# No significant improvement for 4 epoch(s).
#
# ===== Epoch 12/200 =====
# Epoch 12: train loss = 0.3049
# Mean IoU over GT boxes: 0.791
# No significant improvement for 5 epoch(s).
#
# ===== Epoch 13/200 =====
# Epoch 13: train loss = 0.2880
# Mean IoU over GT boxes: 0.796
# No significant improvement for 6 epoch(s).
#
# ===== Epoch 14/200 =====
# Epoch 14: train loss = 0.2749
# Mean IoU over GT boxes: 0.783
# No significant improvement for 7 epoch(s).
#
# ===== Epoch 15/200 =====
# Epoch 15: train loss = 0.2422
# Mean IoU over GT boxes: 0.780
# No significant improvement for 8 epoch(s).
#
# ===== Epoch 16/200 =====
# Epoch 16: train loss = 0.2309
# Mean IoU over GT boxes: 0.764
# No significant improvement for 9 epoch(s).
#
# ===== Epoch 17/200 =====
# Epoch 17: train loss = 0.2133
# Mean IoU over GT boxes: 0.753
# No significant improvement for 10 epoch(s).
#
# ⏹ Early stopping triggered: no improvement > 0.001 for 10 epochs.
#
# Training finished. Best train loss: inf

# %%
save_path = "../models/faster_rcnn_fruits.pth"
os.makedirs(os.path.dirname(save_path), exist_ok=True)

# if we used early stopping and have best_state, save that
if "best_state" in globals() and best_state is not None:
    torch.save(best_state, save_path)
else:
    torch.save(model.state_dict(), save_path)

print("Saved model to:", save_path)
# Out:
# Saved model to: ../models/faster_rcnn_fruits.pth

# %%
test_imgs_dir = "../dataset/test_images/test"
output_dir = "../test_results/faster_rcnn"
os.makedirs(output_dir, exist_ok=True)

score_thresh = 0.5  # confidence threshold
transform = T.ToTensor()

model.eval()

for fname in os.listdir(test_imgs_dir):
    if not fname.lower().endswith((".jpg", ".jpeg", ".png")):
        continue

    img_path = os.path.join(test_imgs_dir, fname)
    img = Image.open(img_path).convert("RGB")
    img_tensor = transform(img).to(DEVICE)

    with torch.no_grad():
        output = model([img_tensor])[0]

    boxes = output["boxes"].cpu()
    scores = output["scores"].cpu()
    labels = output["labels"].cpu()

    draw = ImageDraw.Draw(img)

    for box, score, label in zip(boxes, scores, labels):
        if score < score_thresh:
            continue

        x1, y1, x2, y2 = box.tolist()
        cls_name = CLASS_NAMES[int(label)]

        # Draw box
        draw.rectangle([x1, y1, x2, y2], outline="red", width=3)

        # Draw text (class + score)
        text = f"{cls_name} {score:.2f}"
        draw.text((x1 + 3, y1 + 3), text, fill="yellow")

    out_path = os.path.join(output_dir, fname)
    img.save(out_path)
    print("Saved:", out_path)
# Out:
# Saved: ../test_results/faster_rcnn\apple_77.jpg
# Saved: ../test_results/faster_rcnn\apple_78.jpg
# Saved: ../test_results/faster_rcnn\apple_79.jpg
# Saved: ../test_results/faster_rcnn\apple_80.jpg
# Saved: ../test_results/faster_rcnn\apple_81.jpg
# Saved: ../test_results/faster_rcnn\apple_82.jpg
# Saved: ../test_results/faster_rcnn\apple_83.jpg
# Saved: ../test_results/faster_rcnn\apple_84.jpg
# Saved: ../test_results/faster_rcnn\apple_85.jpg
# Saved: ../test_results/faster_rcnn\apple_86.jpg
# Saved: ../test_results/faster_rcnn\apple_87.jpg
# Saved: ../test_results/faster_rcnn\apple_88.jpg
# Saved: ../test_results/faster_rcnn\apple_89.jpg
# Saved: ../test_results/faster_rcnn\apple_90.jpg
# Saved: ../test_results/faster_rcnn\apple_91.jpg
# Saved: ../test_results/faster_rcnn\apple_92.jpg
# Saved: ../test_results/faster_rcnn\apple_93.jpg
# Saved: ../test_results/faster_rcnn\apple_94.jpg
# Saved: ../test_results/faster_rcnn\apple_95.jpg
# Saved: ../test_results/faster_rcnn\banana_77.jpg
# Saved: ../test_results/faster_rcnn\banana_78.jpg
# Saved: ../test_results/faster_rcnn\banana_79.jpg
# Saved: ../test_results/faster_rcnn\banana_80.jpg
# Saved: ../test_results/faster_rcnn\banana_81.jpg
# Saved: ../test_results/faster_rcnn\banana_82.jpg
# Saved: ../test_results/faster_rcnn\banana_83.jpg
# Saved: ../test_results/faster_rcnn\banana_84.jpg
# Saved: ../test_results/faster_rcnn\banana_85.jpg
# Saved: ../test_results/faster_rcnn\banana_86.jpg
# Saved: ../test_results/faster_rcnn\banana_87.jpg
# Saved: ../test_results/faster_rcnn\banana_88.jpg
# Saved: ../test_results/faster_rcnn\banana_89.jpg
# Saved: ../test_results/faster_rcnn\banana_90.jpg
# Saved: ../test_results/faster_rcnn\banana_91.jpg
# Saved: ../test_results/faster_rcnn\banana_92.jpg
# Saved: ../test_results/faster_rcnn\banana_93.jpg
# Saved: ../test_results/faster_rcnn\banana_94.jpg
# Saved: ../test_results/faster_rcnn\mixed_21.jpg
# Saved: ../test_results/faster_rcnn\mixed_22.jpg
# Saved: ../test_results/faster_rcnn\mixed_23.jpg
# Saved: ../test_results/faster_rcnn\mixed_24.jpg
# Saved: ../test_results/faster_rcnn\mixed_25.jpg
# Saved: ../test_results/faster_rcnn\orange_77.jpg
# Saved: ../test_results/faster_rcnn\orange_78.jpg
# Saved: ../test_results/faster_rcnn\orange_79.jpg
# Saved: ../test_results/faster_rcnn\orange_80.jpg
# Saved: ../test_results/faster_rcnn\orange_81.jpg
# Saved: ../test_results/faster_rcnn\orange_82.jpg
# Saved: ../test_results/faster_rcnn\orange_83.jpg
# Saved: ../test_results/faster_rcnn\orange_84.jpg
# Saved: ../test_results/faster_rcnn\orange_85.jpg
# Saved: ../test_results/faster_rcnn\orange_86.jpg
# Saved: ../test_results/faster_rcnn\orange_87.jpg
# Saved: ../test_results/faster_rcnn\orange_89.jpg
# Saved: ../test_results/faster_rcnn\orange_90.jpg
# Saved: ../test_results/faster_rcnn\orange_91.jpg
# Saved: ../test_results/faster_rcnn\orange_92.jpg
# Saved: ../test_results/faster_rcnn\orange_93.jpg
# Saved: ../test_results/faster_rcnn\orange_94.jpg
# Saved: ../test_results/faster_rcnn\orange_95.jpg
